# %% [markdown]
# ## setup

# %%
import pandas as pd
import cv2
import os

import time

import requests
import json
import urllib

# %% [markdown]
# ## Basic Requests Checkout
#
# MET guideline here:<br>
# https://metmuseum.github.io/

# %%
# checkout all departments
url = "https://collectionapi.metmuseum.org/public/collection/v1/departments"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"departments":[{"departmentId":1,"displayName":"American Decorative Arts"},{"departmentId":3,"displayName":"Ancient Near Eastern Art"},{"departmentId":4,"displayName":"Arms and Armor"},{"departmentId":5,"displayName":"Arts of Africa, Oceania, and the Americas"},{"departmentId":6,"displayName":"Asian Art"},{"departmentId":7,"displayName":"The Cloisters"},{"departmentId":8,"displayName":"The Costume Institute"},{"departmentId":9,"displayName":"Drawings and Prints"},{"departmentId":10,"displayName":"Egyptian Art"},{"departmentId":11,"displayName":"European Paintings"},{"departmentId":12,"displayName":"European Sculpture and Decorative Arts"},{"departmentId":13,"displayName":"Greek and Roman Art"},{"departmentId":14,"displayName":"Islamic Art"},{"departmentId":15,"displayName":"The Robert Lehman Collection"},{"departmentId":16,"displayName":"The Libraries"},{"departmentId":17,"displayName":"Medieval Art"},{"departmentId":18,"displayName":"Musical Instruments"},{"departmentId":19,"displayName":"Photographs"},{"departmentId":21,"displayName":"Modern Art"}]}'

# %%
# search a specific department
url = "https://collectionapi.metmuseum.org/public/collection/v1/objects?departmentIds=8"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
costume_objectsIDs = r.json()['objectIDs']
len(costume_objectsIDs)
# Out:
# 31550

# %%
# Search by a topic
url = "https://collectionapi.metmuseum.org/public/collection/v1/search?q=robe"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.json().keys()
# Out:
# dict_keys(['total', 'objectIDs'])

# %%
# checkout a specific object by object id
url = "https://collectionapi.metmuseum.org/public/collection/v1/objects/53713"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# ## prototype for dataframes concat function

# %%
# to get one object info
x = pd.DataFrame.from_dict(r.json(), orient='index').T
x
# Out:
#   objectID isHighlight accessionNumber accessionYear isPublicDomain  \
# 0    53713       False        32.30.10          1932           True
#
#                                         primaryImage  \
# 0  https://images.metmuseum.org/CRDImages/as/orig...
#
#                                    primaryImageSmall  \
# 0  https://images.metmuseum.org/CRDImages/as/web-...
#
#                                     additionalImages constituents department  \
# 0  [https://images.metmuseum.org/CRDImages/as/ori...         None  Asian Art
#
#    ...        classification rightsAndReproduction linkResource  \
# 0  ...  Costumes-Embroidered
#
#                metadataDate                                repository  \
# 0  2022-10-20T04:55:06.267Z  Metropolitan Museum of Art, New York, NY
#
#                                            objectURL  \
# 0  https://www.metmuseum.org/art/collection/searc...
#
#                                                 tags objectWikidata_URL  \
# 0  [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...
#
#   isTimelineWork GalleryNumber
# 0          False
#
# [1 rows x 57 columns]

# %%
url = "https://collectionapi.metmuseum.org/public/collection/v1/objects/79667"
r = requests.get(url)
r
y = pd.DataFrame.from_dict(r.json(), orient='index').T
y
# Out:
#   objectID isHighlight accessionNumber accessionYear isPublicDomain  \
# 0    79667       False  1997.478.8a, b          1997          False
#
#   primaryImage primaryImageSmall additionalImages  \
# 0                                              []
#
#                                         constituents         department  ...  \
# 0  [{'constituentID': 161959, 'role': 'Designer',...  Costume Institute  ...
#
#   classification rightsAndReproduction linkResource              metadataDate  \
# 0                                                    2022-10-05T04:56:22.043Z
#
#                                  repository  \
# 0  Metropolitan Museum of Art, New York, NY
#
#                                            objectURL  tags objectWikidata_URL  \
# 0  https://www.metmuseum.org/art/collection/searc...  None
#
#   isTimelineWork GalleryNumber
# 0          False
#
# [1 rows x 57 columns]

# %%
pd.concat([x,y])
# Out:
#   objectID isHighlight accessionNumber accessionYear isPublicDomain  \
# 0    53713       False        32.30.10          1932           True
# 0    79667       False  1997.478.8a, b          1997          False
#
#                                         primaryImage  \
# 0  https://images.metmuseum.org/CRDImages/as/orig...
# 0
#
#                                    primaryImageSmall  \
# 0  https://images.metmuseum.org/CRDImages/as/web-...
# 0
#
#                                     additionalImages  \
# 0  [https://images.metmuseum.org/CRDImages/as/ori...
# 0                                                 []
#
#                                         constituents         department  ...  \
# 0                                               None          Asian Art  ...
# 0  [{'constituentID': 161959, 'role': 'Designer',...  Costume Institute  ...
#
#          classification rightsAndReproduction linkResource  \
# 0  Costumes-Embroidered
# 0
#
#                metadataDate                                repository  \
# 0  2022-10-20T04:55:06.267Z  Metropolitan Museum of Art, New York, NY
# 0  2022-10-05T04:56:22.043Z  Metropolitan Museum of Art, New York, NY
#
#                                            objectURL  \
# 0  https://www.metmuseum.org/art/collection/searc...
# 0  https://www.metmuseum.org/art/collection/searc...
#
#                                                 tags objectWikidata_URL  \
# 0  [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...
# 0                                               None
#
#   isTimelineWork GalleryNumber
# 0          False
# 0          False
#
# [2 rows x 57 columns]

# %% [markdown]
# ## scrape: The Costume Institute Department

# %%
type(costume_objectsIDs) # list of objects ID in the costume department created earlier
# Out:
# list

# %%
urlstring = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/'

for id in costume_objectsIDs:
    thisurl = thisurl = urlstring + str(id)
    r = requests.get(thisurl)
    thisdf = pd.DataFrame.from_dict(r.json(), orient='index').T

    df = pd.concat([df,thisdf])

# took 64m53s

# %%
df.to_csv(r'scrapped_data/MET_costume_dept.csv', index = False)

# %%
df = pd.read_csv('scrapped_data/MET_costume_dept.csv')

# %% [markdown]
# ## def function for scrapping

# %% [markdown]
# ### function: get_objectid_list from a certain topic

# %%
# define a function to get the object id list
# of a certain topic
def get_objectid_list(keyword):
    root = "https://collectionapi.metmuseum.org/public/collection/v1/search?q="
    target_url = root + keyword
    r = requests.get(target_url)
    idlist = r.json()['objectIDs']
    print(f'there are {len(idlist)} object(s) about {keyword}')

    return idlist

# %% [markdown]
# ### function: scrapping

# %%
def scrapping(keyword):
   start = time.time()

   target_columns = ['objectID', 'isHighlight', 'accessionNumber', 'accessionYear',
       'isPublicDomain', 'primaryImage', 'primaryImageSmall',
       'additionalImages', 'constituents', 'department', 'objectName', 'title',
       'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
       'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
       'artistAlphaSort', 'artistNationality', 'artistBeginDate',
       'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
       'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
       'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
       'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
       'excavation', 'river', 'classification', 'rightsAndReproduction',
       'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
       'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber']
       
       
   # initiate an empty df
   df = pd.DataFrame(columns=target_columns)

   idlist = get_objectid_list(keyword)

   urlstring = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/'

   for id in idlist:
      thisurl = thisurl = urlstring + str(id)
      r = requests.get(thisurl)
      thisdf = pd.DataFrame.from_dict(r.json(), orient='index').T
      df = pd.concat([df,thisdf])
   
   end = time.time()
   print(f'{end-start} secs slipped...')
   
   return df

# %% [markdown]
# ### function: scrapping using an existing list

# %%
def scrapping_by_idlist(idlist):
   start = time.time()

   target_columns = ['objectID', 'isHighlight', 'accessionNumber', 'accessionYear',
       'isPublicDomain', 'primaryImage', 'primaryImageSmall',
       'additionalImages', 'constituents', 'department', 'objectName', 'title',
       'culture', 'period', 'dynasty', 'reign', 'portfolio', 'artistRole',
       'artistPrefix', 'artistDisplayName', 'artistDisplayBio', 'artistSuffix',
       'artistAlphaSort', 'artistNationality', 'artistBeginDate',
       'artistEndDate', 'artistGender', 'artistWikidata_URL', 'artistULAN_URL',
       'objectDate', 'objectBeginDate', 'objectEndDate', 'medium',
       'dimensions', 'measurements', 'creditLine', 'geographyType', 'city',
       'state', 'county', 'country', 'region', 'subregion', 'locale', 'locus',
       'excavation', 'river', 'classification', 'rightsAndReproduction',
       'linkResource', 'metadataDate', 'repository', 'objectURL', 'tags',
       'objectWikidata_URL', 'isTimelineWork', 'GalleryNumber']
       
       
   # initiate an empty df
   df = pd.DataFrame(columns=target_columns)

   urlstring = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/'

   for id in idlist:
      thisurl = thisurl = urlstring + str(id)
      r = requests.get(thisurl)
      thisdf = pd.DataFrame.from_dict(r.json(), orient='index').T
      df = pd.concat([df,thisdf])
   
   end = time.time()
   print(f'{end-start} secs slipped...')
   
   return df

# %% [markdown]
# ### function: download_img

# %%
def download_img(df,dir='testing/'):
    start = time.time()
    print(f'{df.shape[0]} images will be downloaded.')

    name = df['objectID']
    url = df['primaryImage']

    name = list(name)
    url = list(url)

    error_id = []
    error_n = 0

    for n,u in zip(name,url):
        filename = dir + str(n) + '.jpg'
        try:
            z = urllib.request.urlopen(u)
            output = open(filename, 'wb')
            output.write(z.read())
            output.close()
        except:
            error_id.append(n)
            print(f'error id {n}')
            error_n += 1
            print(f'{error_n} errors in total')
            continue


    end = time.time()
    print(f'{end - start} secs slipped...')

# %% [markdown]
# ## scrape: robe
#
# this is a test batch, for detecting filtering issues
#
# found issues:
# - unrelated topics: may be fixed by filtering classification, single word topic
# - black & white

# %% [markdown]
# ### download dataframe

# %%
df_robe = scrapping('robe')
# Out:
# there are 2470 object(s) about robe
# 685.2680084705353 secs slipped...

# %%
df_robe
# Out:
#    objectID isHighlight accessionNumber accessionYear isPublicDomain  \
# 0     53715       False          43.119          1943           True
# 0    450958       False      48.187.667          1948          False
# 0    751497        True        2017.717          2017           True
# 0     85512       False      1975.344.4          1975          False
# 0    227775       False          54.203          1954          False
# ..      ...         ...             ...           ...            ...
# 0    352478       False           38.52          1938           True
# 0    368861       False    25.62.32r(a)          1925          False
# 0    361192       False     20.81.3.167          1920          False
# 0    770912       False      18.17.1-45          1918          False
# 0    825669       False        2022.247          2022          False
#
#                                          primaryImage  \
# 0   https://images.metmuseum.org/CRDImages/as/orig...
# 0
# 0   https://images.metmuseum.org/CRDImages/ad/orig...
# 0
# 0
# ..                                                ...
# 0   https://images.metmuseum.org/CRDImages/dp/orig...
# 0
# 0
# 0
# 0
#
#                                     primaryImageSmall  \
# 0   https://images.metmuseum.org/CRDImages/as/web-...
# 0
# 0   https://images.metmuseum.org/CRDImages/ad/web-...
# 0
# 0
# ..                                                ...
# 0   https://images.metmuseum.org/CRDImages/dp/web-...
# 0
# 0
# 0
# 0
#
#                                      additionalImages  \
# 0                                                  []
# 0                                                  []
# 0                                                  []
# 0                                                  []
# 0                                                  []
# ..                                                ...
# 0   [https://images.metmuseum.org/CRDImages/dp/ori...
# 0                                                  []
# 0                                                  []
# 0                                                  []
# 0                                                  []
#
#                                          constituents  \
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# ..                                                ...
# 0   [{'constituentID': 83628, 'role': 'Editor', 'n...
# 0   [{'constituentID': 166181, 'role': 'Artist', '...
# 0   [{'constituentID': 212471, 'role': 'Etcher', '...
# 0   [{'constituentID': 95757, 'role': 'Artist', 'n...
# 0   [{'constituentID': 11354, 'role': 'Artist', 'n...
#
#                                 department  ... rightsAndReproduction  \
# 0                                Asian Art  ...
# 0                              Islamic Art  ...
# 0                        The American Wing  ...
# 0                              Islamic Art  ...
# 0   European Sculpture and Decorative Arts  ...
# ..                                     ...  ...                   ...
# 0                      Drawings and Prints  ...
# 0                      Drawings and Prints  ...
# 0                      Drawings and Prints  ...
# 0                      Drawings and Prints  ...
# 0                                Asian Art  ...
#
#    linkResource              metadataDate  \
# 0                2022-10-20T04:55:06.267Z
# 0                2021-11-29T10:04:10.363Z
# 0                 2022-06-02T12:28:57.13Z
# 0                2020-12-30T04:37:58.547Z
# 0                2022-02-09T04:42:08.947Z
# ..          ...                       ...
# 0                2022-10-20T04:55:06.267Z
# 0                 2021-08-20T04:36:13.79Z
# 0                 2021-08-20T04:36:13.79Z
# 0                  2021-06-05T04:45:37.2Z
# 0                 2022-10-25T09:51:51.09Z
#
#                                   repository  \
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# ..                                       ...
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
# 0   Metropolitan Museum of Art, New York, NY
#
#                                             objectURL  \
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# ..                                                ...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
# 0   https://www.metmuseum.org/art/collection/searc...
#
#                                                  tags  \
# 0   [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...
# 0   [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...
# 0                                                None
# 0   [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...
# 0   [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...
# ..                                                ...
# 0   [{'term': 'Men', 'AAT_URL': 'http://vocab.gett...
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
#
#                           objectWikidata_URL isTimelineWork GalleryNumber  \
# 0                                                     False           214
# 0                                                     False
# 0   https://www.wikidata.org/wiki/Q104413096          False
# 0                                                     False
# 0                                                     False
# ..                                       ...            ...           ...
# 0                                                      True
# 0                                                     False
# 0                                                     False
# 0                                                     False
# 0                                                     False
#
#    message
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# ..     ...
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
#
# [2470 rows x 58 columns]

# %%
df_robe.to_csv(r'scrapped_data/MET_robe.csv', index = False)

# %% [markdown]
# ### prepare to download image

# %%
df_robe = pd.read_csv('scrapped_data/MET_robe.csv')

# %%
df_robe.shape
# Out:
# (2470, 58)

# %%
condition1 = (df_robe['isPublicDomain'] == True) # select the ones is public domain
condition2 = (df_robe['primaryImage'] != '') # select the ones has primary images

df_sel = df_robe.loc[condition1 & condition2]

# %%
df_sel['classification'].unique()
# Out:
# array(['Costumes-Embroidered', nan, 'Main dress-Womenswear', 'Main dress',
#        'Outerwear-Womenswear', 'Main dress-Menswear',
#        'Night and Dressing Wear', 'Costumes', 'Textiles-Costumes',
#        'Costumes-Tapestries', 'Ceramics', 'Textiles-Embroidered',
#        'Main dress-Childrenswear', 'Crèche', 'Paintings',
#        'Costumes-Woven', 'Textiles-Woven', 'Textiles-Velvets',
#        'Sculpture', 'Hide-Costumes', 'Codices', 'Textiles-Laces',
#        'Glass-Stained', 'Prints', 'Photographs', 'Textiles-Tapestries',
#        'Drawings', 'Lacquer', 'Furniture', 'Costumes-Velvets', 'Textiles',
#        'Metalwork-Lead', 'Textiles-Painted and Dyed',
#        'Textiles-Painted and Printed', 'Calligraphy',
#        'Textiles-Dyed and Embroidered', 'Outerwear-Menswear', 'Netsuke',
#        'Illustrated Books', 'Lapidary Work-Sardonyx', 'Metalwork-Silver',
#        'Metalwork', 'Jade', 'Enamels-Basse taille', 'Inrō',
#        'Textiles-Dyed', 'Idiophone-Shaken-crotal bell', 'Sculpture-Stone',
#        'Gold and Silver', 'Horology', 'Sculpture-Wood', 'Paintings-Icons',
#        'Ceramics-Tiles', 'Ivories', 'Sculpture-Architectural',
#        'Wood-Paintings', 'Enamels-Champlevé', 'Ivories-Elephant',
#        'Ceramics-Porcelain', 'Woodwork-Furniture',
#        'Metalwork-Gold and Platinum', 'Terracottas',
#        'Textiles-Ecclesiastical', 'Shafted Weapons', 'Metal', 'Woodwork',
#        'Lapidary Work-Gems', 'Paintings-Panels',
#        'Idiophone-Struck-bell-clapper', 'Rubbing', 'Stencils',
#        'Textiles-Costumes-Ecclesiastical', 'Stone', 'Books',
#        'Sword Furniture-Tsuba', 'Cloisonné',
#        'Manuscripts and Illuminations', 'Ivories-Walrus',
#        'Ceramics-Pottery', 'Medals and Plaquettes', 'Sculpture-Bronze',
#        'Sculpture-Miniature', 'Glass', 'Masks', 'Coins', 'Glass-Painted',
#        'Medals', 'Sculpture-Miniature-Wood', 'Textiles-Brocades',
#        'Armor for Man', 'Armor for Horse and Man', 'Ceramics-Vessels',
#        'Parchment', 'Soapstone', 'Hide-Documents', 'Aerophone-Organ',
#        'Enamels', 'Wood-Containers', 'Ceramics-Sculpture', 'Albums',
#        'Sculpture-Marble', 'Stucco-Sculpture', 'Bone/Ivory-Sculpture',
#        'Enamels-Painted', 'Metal-Sculpture', 'Miniatures',
#        'paintings: shrouds, bandages, and other'], dtype=object)

# %%
sel = ['Costumes-Embroidered', 'Main dress-Womenswear', 'Main dress',
       'Outerwear-Womenswear', 'Main dress-Menswear',
       'Night and Dressing Wear', 'Costumes', 'Textiles-Costumes',
       'Costumes-Tapestries', 'Ceramics', 'Textiles-Embroidered',
       'Main dress-Childrenswear', 
       'Costumes-Woven', 'Costumes-Velvets', 'Outerwear-Menswear']

df_sel[df_sel['classification'].isin(sel)]
# Out:
#       objectID isHighlight accessionNumber  accessionYear isPublicDomain  \
# 0      53715.0       False          43.119         1943.0           True
# 21     86241.0       False        C.I.69.5         1969.0           True
# 22     85550.0       False       C.I.54.15         1954.0           True
# 23     85503.0       False      1975.388.1         1975.0           True
# 28    126846.0       False     C.I.41.86.7         1941.0           True
# ...        ...         ...             ...            ...            ...
# 2185  448246.0       False      29.106a, b         1929.0           True
# 2225  229059.0       False     64.101.1363         1964.0           True
# 2262  447958.0       False         27.13.9         1927.0           True
# 2284  452400.0       False      1972.120.3         1972.0           True
# 2404  448952.0       False        33.80.18         1933.0           True
#
#                                            primaryImage  \
# 0     https://images.metmuseum.org/CRDImages/as/orig...
# 21    https://images.metmuseum.org/CRDImages/is/orig...
# 22    https://images.metmuseum.org/CRDImages/is/orig...
# 23    https://images.metmuseum.org/CRDImages/is/orig...
# 28    https://images.metmuseum.org/CRDImages/is/orig...
# ...                                                 ...
# 2185  https://images.metmuseum.org/CRDImages/is/orig...
# 2225  https://images.metmuseum.org/CRDImages/es/orig...
# 2262  https://images.metmuseum.org/CRDImages/is/orig...
# 2284  https://images.metmuseum.org/CRDImages/is/orig...
# 2404  https://images.metmuseum.org/CRDImages/is/orig...
#
#                                       primaryImageSmall  \
# 0     https://images.metmuseum.org/CRDImages/as/web-...
# 21    https://images.metmuseum.org/CRDImages/is/web-...
# 22    https://images.metmuseum.org/CRDImages/is/web-...
# 23    https://images.metmuseum.org/CRDImages/is/web-...
# 28    https://images.metmuseum.org/CRDImages/is/web-...
# ...                                                 ...
# 2185  https://images.metmuseum.org/CRDImages/is/web-...
# 2225  https://images.metmuseum.org/CRDImages/es/web-...
# 2262  https://images.metmuseum.org/CRDImages/is/web-...
# 2284  https://images.metmuseum.org/CRDImages/is/web-...
# 2404  https://images.metmuseum.org/CRDImages/is/web-...
#
#                                        additionalImages constituents  \
# 0                                                    []          NaN
# 21    ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 22    ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 23    ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 28                                                   []          NaN
# ...                                                 ...          ...
# 2185  ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 2225  ['https://images.metmuseum.org/CRDImages/es/or...          NaN
# 2262  ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 2284  ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# 2404  ['https://images.metmuseum.org/CRDImages/is/or...          NaN
#
#                                   department  ... rightsAndReproduction  \
# 0                                  Asian Art  ...                   NaN
# 21                               Islamic Art  ...                   NaN
# 22                               Islamic Art  ...                   NaN
# 23                               Islamic Art  ...                   NaN
# 28                               Islamic Art  ...                   NaN
# ...                                      ...  ...                   ...
# 2185                             Islamic Art  ...                   NaN
# 2225  European Sculpture and Decorative Arts  ...                   NaN
# 2262                             Islamic Art  ...                   NaN
# 2284                             Islamic Art  ...                   NaN
# 2404                             Islamic Art  ...                   NaN
#
#      linkResource              metadataDate  \
# 0             NaN  2022-10-20T04:55:06.267Z
# 21            NaN  2021-04-20T04:40:27.437Z
# 22            NaN  2021-04-20T04:40:27.437Z
# 23            NaN  2021-04-06T04:41:04.967Z
# 28            NaN  2022-10-20T04:55:06.267Z
# ...           ...                       ...
# 2185          NaN  2022-09-09T04:54:13.663Z
# 2225          NaN  2021-06-29T04:39:38.347Z
# 2262          NaN  2022-10-20T04:55:06.267Z
# 2284          NaN  2022-10-20T04:55:06.267Z
# 2404          NaN   2021-09-01T04:36:10.75Z
#
#                                     repository  \
# 0     Metropolitan Museum of Art, New York, NY
# 21    Metropolitan Museum of Art, New York, NY
# 22    Metropolitan Museum of Art, New York, NY
# 23    Metropolitan Museum of Art, New York, NY
# 28    Metropolitan Museum of Art, New York, NY
# ...                                        ...
# 2185  Metropolitan Museum of Art, New York, NY
# 2225  Metropolitan Museum of Art, New York, NY
# 2262  Metropolitan Museum of Art, New York, NY
# 2284  Metropolitan Museum of Art, New York, NY
# 2404  Metropolitan Museum of Art, New York, NY
#
#                                               objectURL  \
# 0     https://www.metmuseum.org/art/collection/searc...
# 21    https://www.metmuseum.org/art/collection/searc...
# 22    https://www.metmuseum.org/art/collection/searc...
# 23    https://www.metmuseum.org/art/collection/searc...
# 28    https://www.metmuseum.org/art/collection/searc...
# ...                                                 ...
# 2185  https://www.metmuseum.org/art/collection/searc...
# 2225  https://www.metmuseum.org/art/collection/searc...
# 2262  https://www.metmuseum.org/art/collection/searc...
# 2284  https://www.metmuseum.org/art/collection/searc...
# 2404  https://www.metmuseum.org/art/collection/searc...
#
#                                                    tags objectWikidata_URL  \
# 0     [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...                NaN
# 21    [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...                NaN
# 22    [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...                NaN
# 23    [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...                NaN
# 28    [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...                NaN
# ...                                                 ...                ...
# 2185  [{'term': 'Men', 'AAT_URL': 'http://vocab.gett...                NaN
# 2225  [{'term': 'Faces', 'AAT_URL': 'http://vocab.ge...                NaN
# 2262                                                NaN                NaN
# 2284                                                NaN                NaN
# 2404  [{'term': 'Flowers', 'AAT_URL': 'http://vocab....                NaN
#
#      isTimelineWork GalleryNumber message
# 0             False         214.0     NaN
# 21            False           NaN     NaN
# 22            False           NaN     NaN
# 23            False           NaN     NaN
# 28            False           NaN     NaN
# ...             ...           ...     ...
# 2185          False           NaN     NaN
# 2225           True           NaN     NaN
# 2262           True           NaN     NaN
# 2284           True           NaN     NaN
# 2404           True           NaN     NaN
#
# [478 rows x 58 columns]

# %%
df_sel['department'].value_counts()
# Out:
# Asian Art                                 781
# European Paintings                        159
# Costume Institute                         149
# Drawings and Prints                       126
# Islamic Art                               121
# European Sculpture and Decorative Arts     79
# Ancient Near Eastern Art                   54
# Medieval Art                               30
# The Cloisters                              28
# Photographs                                26
# Robert Lehman Collection                   24
# The Michael C. Rockefeller Wing            11
# The American Wing                          11
# Egyptian Art                               10
# Arms and Armor                              8
# Greek and Roman Art                         4
# Musical Instruments                         3
# Name: department, dtype: int64

# %%
df_sel['objectID'] = df_sel['objectID'].astype('int')
# Out:
# <ipython-input-108-46fe0f398f49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel['objectID'] = df_sel['objectID'].astype('int')

# %%
df_sel[df_sel['objectName'].str.contains('robe')==True]
# Out:
#       objectID isHighlight accessionNumber  accessionYear isPublicDomain  \
# 2       751497        True        2017.717         2017.0           True
# 115      69855       False        46.187.6         1946.0           True
# 120      68577       False        30.75.98         1930.0           True
# 132     229782       False   1983.574.2a–c         1983.0           True
# 134     454043       False     2003.416a–e         2001.0           True
# ...        ...         ...             ...            ...            ...
# 803      70233       False         58.97.2         1958.0           True
# 892      70397       False          65.217         1965.0           True
# 901      53619       False        45.123.4         1945.0           True
# 1028     61806       False     2001.428.23         2001.0           True
# 1346     55960       False         1972.18         1972.0           True
#
#                                            primaryImage  \
# 2     https://images.metmuseum.org/CRDImages/ad/orig...
# 115   https://images.metmuseum.org/CRDImages/as/orig...
# 120   https://images.metmuseum.org/CRDImages/as/orig...
# 132   https://images.metmuseum.org/CRDImages/es/orig...
# 134   https://images.metmuseum.org/CRDImages/is/orig...
# ...                                                 ...
# 803   https://images.metmuseum.org/CRDImages/as/orig...
# 892   https://images.metmuseum.org/CRDImages/as/orig...
# 901   https://images.metmuseum.org/CRDImages/as/orig...
# 1028  https://images.metmuseum.org/CRDImages/as/orig...
# 1346  https://images.metmuseum.org/CRDImages/as/orig...
#
#                                       primaryImageSmall  \
# 2     https://images.metmuseum.org/CRDImages/ad/web-...
# 115   https://images.metmuseum.org/CRDImages/as/web-...
# 120   https://images.metmuseum.org/CRDImages/as/web-...
# 132   https://images.metmuseum.org/CRDImages/es/web-...
# 134   https://images.metmuseum.org/CRDImages/is/web-...
# ...                                                 ...
# 803   https://images.metmuseum.org/CRDImages/as/web-...
# 892   https://images.metmuseum.org/CRDImages/as/web-...
# 901   https://images.metmuseum.org/CRDImages/as/web-...
# 1028  https://images.metmuseum.org/CRDImages/as/web-...
# 1346  https://images.metmuseum.org/CRDImages/as/web-...
#
#                                        additionalImages constituents  \
# 2                                                    []          NaN
# 115                                                  []          NaN
# 120   ['https://images.metmuseum.org/CRDImages/as/or...          NaN
# 132   ['https://images.metmuseum.org/CRDImages/es/or...          NaN
# 134   ['https://images.metmuseum.org/CRDImages/is/or...          NaN
# ...                                                 ...          ...
# 803   ['https://images.metmuseum.org/CRDImages/as/or...          NaN
# 892                                                  []          NaN
# 901   ['https://images.metmuseum.org/CRDImages/as/or...          NaN
# 1028                                                 []          NaN
# 1346  ['https://images.metmuseum.org/CRDImages/as/or...          NaN
#
#                                   department  ... rightsAndReproduction  \
# 2                          The American Wing  ...                   NaN
# 115                                Asian Art  ...                   NaN
# 120                                Asian Art  ...                   NaN
# 132   European Sculpture and Decorative Arts  ...                   NaN
# 134                              Islamic Art  ...                   NaN
# ...                                      ...  ...                   ...
# 803                                Asian Art  ...                   NaN
# 892                                Asian Art  ...                   NaN
# 901                                Asian Art  ...                   NaN
# 1028                               Asian Art  ...                   NaN
# 1346                               Asian Art  ...                   NaN
#
#      linkResource              metadataDate  \
# 2             NaN   2022-06-02T12:28:57.13Z
# 115           NaN  2022-10-20T04:55:06.267Z
# 120           NaN   2022-09-13T04:54:15.93Z
# 132           NaN  2020-09-16T18:35:19.457Z
# 134           NaN  2022-10-20T04:55:06.267Z
# ...           ...                       ...
# 803           NaN  2022-10-20T04:55:06.267Z
# 892           NaN  2022-04-22T05:09:02.033Z
# 901           NaN  2022-10-20T04:55:06.267Z
# 1028          NaN  2022-10-20T04:55:06.267Z
# 1346          NaN      2021-12-01T04:35:59Z
#
#                                     repository  \
# 2     Metropolitan Museum of Art, New York, NY
# 115   Metropolitan Museum of Art, New York, NY
# 120   Metropolitan Museum of Art, New York, NY
# 132   Metropolitan Museum of Art, New York, NY
# 134   Metropolitan Museum of Art, New York, NY
# ...                                        ...
# 803   Metropolitan Museum of Art, New York, NY
# 892   Metropolitan Museum of Art, New York, NY
# 901   Metropolitan Museum of Art, New York, NY
# 1028  Metropolitan Museum of Art, New York, NY
# 1346  Metropolitan Museum of Art, New York, NY
#
#                                               objectURL  \
# 2     https://www.metmuseum.org/art/collection/searc...
# 115   https://www.metmuseum.org/art/collection/searc...
# 120   https://www.metmuseum.org/art/collection/searc...
# 132   https://www.metmuseum.org/art/collection/searc...
# 134   https://www.metmuseum.org/art/collection/searc...
# ...                                                 ...
# 803   https://www.metmuseum.org/art/collection/searc...
# 892   https://www.metmuseum.org/art/collection/searc...
# 901   https://www.metmuseum.org/art/collection/searc...
# 1028  https://www.metmuseum.org/art/collection/searc...
# 1346  https://www.metmuseum.org/art/collection/searc...
#
#                                                    tags  \
# 2                                                   NaN
# 115   [{'term': 'Peonies', 'AAT_URL': 'http://vocab....
# 120                                                 NaN
# 132   [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...
# 134                                                 NaN
# ...                                                 ...
# 803                                                 NaN
# 892   [{'term': 'Dragons', 'AAT_URL': 'http://vocab....
# 901   [{'term': 'Costumes', 'AAT_URL': 'http://vocab...
# 1028  [{'term': 'Leaves', 'AAT_URL': 'http://vocab.g...
# 1346  [{'term': 'Books', 'AAT_URL': 'http://vocab.ge...
#
#                             objectWikidata_URL isTimelineWork GalleryNumber  \
# 2     https://www.wikidata.org/wiki/Q104413096          False           NaN
# 115                                        NaN          False           NaN
# 120                                        NaN          False         213.0
# 132                                        NaN          False           NaN
# 134                                        NaN           True         460.0
# ...                                        ...            ...           ...
# 803                                        NaN          False           NaN
# 892                                        NaN          False           NaN
# 901                                        NaN          False           NaN
# 1028                                       NaN          False           NaN
# 1346                                       NaN          False           NaN
#
#      message
# 2        NaN
# 115      NaN
# 120      NaN
# 132      NaN
# 134      NaN
# ...      ...
# 803      NaN
# 892      NaN
# 901      NaN
# 1028     NaN
# 1346     NaN
#
# [83 rows x 58 columns]

# %%
df_sel[df_sel['title'].str.contains('robe') == True]
# Out:
#       objectID isHighlight accessionNumber  accessionYear isPublicDomain  \
# 0        53715       False          43.119         1943.0           True
# 2       751497        True        2017.717         2017.0           True
# 116      69900       False       49.32.125         1949.0           True
# 120      68577       False        30.75.98         1930.0           True
# 132     229782       False   1983.574.2a–c         1983.0           True
# ...        ...         ...             ...            ...            ...
# 1346     55960       False         1972.18         1972.0           True
# 1348    816191       False   2018.853.4a–c         2018.0           True
# 1685    675966       False      2015.741.9         2015.0           True
# 1686    675971       False     2015.741.14         2015.0           True
# 1757    324597       False         57.27.3         1957.0           True
#
#                                            primaryImage  \
# 0     https://images.metmuseum.org/CRDImages/as/orig...
# 2     https://images.metmuseum.org/CRDImages/ad/orig...
# 116   https://images.metmuseum.org/CRDImages/as/orig...
# 120   https://images.metmuseum.org/CRDImages/as/orig...
# 132   https://images.metmuseum.org/CRDImages/es/orig...
# ...                                                 ...
# 1346  https://images.metmuseum.org/CRDImages/as/orig...
# 1348  https://images.metmuseum.org/CRDImages/as/orig...
# 1685  https://images.metmuseum.org/CRDImages/es/orig...
# 1686  https://images.metmuseum.org/CRDImages/es/orig...
# 1757  https://images.metmuseum.org/CRDImages/an/orig...
#
#                                       primaryImageSmall  \
# 0     https://images.metmuseum.org/CRDImages/as/web-...
# 2     https://images.metmuseum.org/CRDImages/ad/web-...
# 116   https://images.metmuseum.org/CRDImages/as/web-...
# 120   https://images.metmuseum.org/CRDImages/as/web-...
# 132   https://images.metmuseum.org/CRDImages/es/web-...
# ...                                                 ...
# 1346  https://images.metmuseum.org/CRDImages/as/web-...
# 1348  https://images.metmuseum.org/CRDImages/as/web-...
# 1685  https://images.metmuseum.org/CRDImages/es/web-...
# 1686  https://images.metmuseum.org/CRDImages/es/web-...
# 1757  https://images.metmuseum.org/CRDImages/an/web-...
#
#                                        additionalImages  \
# 0                                                    []
# 2                                                    []
# 116   ['https://images.metmuseum.org/CRDImages/as/or...
# 120   ['https://images.metmuseum.org/CRDImages/as/or...
# 132   ['https://images.metmuseum.org/CRDImages/es/or...
# ...                                                 ...
# 1346  ['https://images.metmuseum.org/CRDImages/as/or...
# 1348  ['https://images.metmuseum.org/CRDImages/as/or...
# 1685  ['https://images.metmuseum.org/CRDImages/es/or...
# 1686  ['https://images.metmuseum.org/CRDImages/es/or...
# 1757  ['https://images.metmuseum.org/CRDImages/an/or...
#
#                                            constituents  \
# 0                                                   NaN
# 2                                                   NaN
# 116                                                 NaN
# 120                                                 NaN
# 132                                                 NaN
# ...                                                 ...
# 1346                                                NaN
# 1348  [{'constituentID': 37502, 'role': 'Artist', 'n...
# 1685                                                NaN
# 1686                                                NaN
# 1757                                                NaN
#
#                                   department  ... rightsAndReproduction  \
# 0                                  Asian Art  ...                   NaN
# 2                          The American Wing  ...                   NaN
# 116                                Asian Art  ...                   NaN
# 120                                Asian Art  ...                   NaN
# 132   European Sculpture and Decorative Arts  ...                   NaN
# ...                                      ...  ...                   ...
# 1346                               Asian Art  ...                   NaN
# 1348                               Asian Art  ...                   NaN
# 1685  European Sculpture and Decorative Arts  ...                   NaN
# 1686  European Sculpture and Decorative Arts  ...                   NaN
# 1757                Ancient Near Eastern Art  ...                   NaN
#
#      linkResource              metadataDate  \
# 0             NaN  2022-10-20T04:55:06.267Z
# 2             NaN   2022-06-02T12:28:57.13Z
# 116           NaN  2022-10-20T04:55:06.267Z
# 120           NaN   2022-09-13T04:54:15.93Z
# 132           NaN  2020-09-16T18:35:19.457Z
# ...           ...                       ...
# 1346          NaN      2021-12-01T04:35:59Z
# 1348          NaN   2022-06-02T12:28:57.13Z
# 1685          NaN  2022-05-20T05:08:55.267Z
# 1686          NaN  2022-05-20T05:08:55.267Z
# 1757          NaN   2021-04-15T04:40:52.63Z
#
#                                     repository  \
# 0     Metropolitan Museum of Art, New York, NY
# 2     Metropolitan Museum of Art, New York, NY
# 116   Metropolitan Museum of Art, New York, NY
# 120   Metropolitan Museum of Art, New York, NY
# 132   Metropolitan Museum of Art, New York, NY
# ...                                        ...
# 1346  Metropolitan Museum of Art, New York, NY
# 1348  Metropolitan Museum of Art, New York, NY
# 1685  Metropolitan Museum of Art, New York, NY
# 1686  Metropolitan Museum of Art, New York, NY
# 1757  Metropolitan Museum of Art, New York, NY
#
#                                               objectURL  \
# 0     https://www.metmuseum.org/art/collection/searc...
# 2     https://www.metmuseum.org/art/collection/searc...
# 116   https://www.metmuseum.org/art/collection/searc...
# 120   https://www.metmuseum.org/art/collection/searc...
# 132   https://www.metmuseum.org/art/collection/searc...
# ...                                                 ...
# 1346  https://www.metmuseum.org/art/collection/searc...
# 1348  https://www.metmuseum.org/art/collection/searc...
# 1685  https://www.metmuseum.org/art/collection/searc...
# 1686  https://www.metmuseum.org/art/collection/searc...
# 1757  https://www.metmuseum.org/art/collection/searc...
#
#                                                    tags  \
# 0     [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...
# 2                                                   NaN
# 116   [{'term': 'Cranes', 'AAT_URL': 'http://vocab.g...
# 120                                                 NaN
# 132   [{'term': 'Robes', 'AAT_URL': 'http://vocab.ge...
# ...                                                 ...
# 1346  [{'term': 'Books', 'AAT_URL': 'http://vocab.ge...
# 1348                                                NaN
# 1685  [{'term': 'Men', 'AAT_URL': 'http://vocab.gett...
# 1686  [{'term': 'Men', 'AAT_URL': 'http://vocab.gett...
# 1757  [{'term': 'Animals', 'AAT_URL': 'http://vocab....
#
#                             objectWikidata_URL isTimelineWork GalleryNumber  \
# 0                                          NaN          False         214.0
# 2     https://www.wikidata.org/wiki/Q104413096          False           NaN
# 116                                        NaN          False         213.0
# 120                                        NaN          False         213.0
# 132                                        NaN          False           NaN
# ...                                        ...            ...           ...
# 1346                                       NaN          False           NaN
# 1348   https://www.wikidata.org/wiki/Q78610277          False           NaN
# 1685                                       NaN          False           NaN
# 1686                                       NaN          False           NaN
# 1757                                       NaN          False           NaN
#
#      message
# 0        NaN
# 2        NaN
# 116      NaN
# 120      NaN
# 132      NaN
# ...      ...
# 1346     NaN
# 1348     NaN
# 1685     NaN
# 1686     NaN
# 1757     NaN
#
# [65 rows x 58 columns]

# %%
df_sel = df_sel[df_sel['primaryImage'].isna() != True]
df_sel.shape
# Out:
# (1623, 58)

# %%
df_sel
# Out:
#       objectID isHighlight accessionNumber  accessionYear isPublicDomain  \
# 0        53715       False          43.119         1943.0           True
# 2       751497        True        2017.717         2017.0           True
# 7       108103       False      1975.227.9         1975.0           True
# 8       102549       False           45.73         1945.0           True
# 9       107996       False       1972.78.3         1972.0           True
# ...        ...         ...             ...            ...            ...
# 2459    436797       False       41.190.19         1941.0           True
# 2460     53233       False     2015.300.67         2015.0           True
# 2461    435838       False         05.39.2         1905.0           True
# 2462    435640       False       30.95.256         1930.0           True
# 2465    352478       False           38.52         1938.0           True
#
#                                            primaryImage  \
# 0     https://images.metmuseum.org/CRDImages/as/orig...
# 2     https://images.metmuseum.org/CRDImages/ad/orig...
# 7     https://images.metmuseum.org/CRDImages/ci/orig...
# 8     https://images.metmuseum.org/CRDImages/ci/orig...
# 9     https://images.metmuseum.org/CRDImages/ci/orig...
# ...                                                 ...
# 2459  https://images.metmuseum.org/CRDImages/ep/orig...
# 2460  https://images.metmuseum.org/CRDImages/as/orig...
# 2461  https://images.metmuseum.org/CRDImages/ep/orig...
# 2462  https://images.metmuseum.org/CRDImages/ep/orig...
# 2465  https://images.metmuseum.org/CRDImages/dp/orig...
#
#                                       primaryImageSmall  \
# 0     https://images.metmuseum.org/CRDImages/as/web-...
# 2     https://images.metmuseum.org/CRDImages/ad/web-...
# 7     https://images.metmuseum.org/CRDImages/ci/web-...
# 8     https://images.metmuseum.org/CRDImages/ci/web-...
# 9     https://images.metmuseum.org/CRDImages/ci/web-...
# ...                                                 ...
# 2459  https://images.metmuseum.org/CRDImages/ep/web-...
# 2460  https://images.metmuseum.org/CRDImages/as/web-...
# 2461  https://images.metmuseum.org/CRDImages/ep/web-...
# 2462  https://images.metmuseum.org/CRDImages/ep/web-...
# 2465  https://images.metmuseum.org/CRDImages/dp/web-...
#
#                                        additionalImages  \
# 0                                                    []
# 2                                                    []
# 7     ['https://images.metmuseum.org/CRDImages/ci/or...
# 8                                                    []
# 9     ['https://images.metmuseum.org/CRDImages/ci/or...
# ...                                                 ...
# 2459  ['https://images.metmuseum.org/CRDImages/ep/or...
# 2460  ['https://images.metmuseum.org/CRDImages/as/or...
# 2461  ['https://images.metmuseum.org/CRDImages/ep/or...
# 2462                                                 []
# 2465  ['https://images.metmuseum.org/CRDImages/dp/or...
#
#                                            constituents           department  \
# 0                                                   NaN            Asian Art
# 2                                                   NaN    The American Wing
# 7                                                   NaN    Costume Institute
# 8                                                   NaN    Costume Institute
# 9                                                   NaN    Costume Institute
# ...                                                 ...                  ...
# 2459  [{'constituentID': 162015, 'role': 'Artist', '...   European Paintings
# 2460  [{'constituentID': 11724, 'role': 'Artist', 'n...            Asian Art
# 2461  [{'constituentID': 161740, 'role': 'Artist', '...   European Paintings
# 2462  [{'constituentID': 161668, 'role': 'Artist', '...   European Paintings
# 2465  [{'constituentID': 83628, 'role': 'Editor', 'n...  Drawings and Prints
#
#       ... rightsAndReproduction linkResource              metadataDate  \
# 0     ...                   NaN          NaN  2022-10-20T04:55:06.267Z
# 2     ...                   NaN          NaN   2022-06-02T12:28:57.13Z
# 7     ...                   NaN          NaN  2020-03-02T21:50:01.377Z
# 8     ...                   NaN          NaN  2020-03-02T21:50:01.377Z
# 9     ...                   NaN          NaN  2020-03-02T21:50:01.377Z
# ...   ...                   ...          ...                       ...
# 2459  ...                   NaN          NaN    2022-11-02T04:54:43.4Z
# 2460  ...                   NaN          NaN  2022-10-20T04:55:06.267Z
# 2461  ...                   NaN          NaN  2022-10-31T04:54:57.077Z
# 2462  ...                   NaN          NaN  2022-10-31T04:54:57.077Z
# 2465  ...                   NaN          NaN  2022-10-20T04:55:06.267Z
#
#                                     repository  \
# 0     Metropolitan Museum of Art, New York, NY
# 2     Metropolitan Museum of Art, New York, NY
# 7     Metropolitan Museum of Art, New York, NY
# 8     Metropolitan Museum of Art, New York, NY
# 9     Metropolitan Museum of Art, New York, NY
# ...                                        ...
# 2459  Metropolitan Museum of Art, New York, NY
# 2460  Metropolitan Museum of Art, New York, NY
# 2461  Metropolitan Museum of Art, New York, NY
# 2462  Metropolitan Museum of Art, New York, NY
# 2465  Metropolitan Museum of Art, New York, NY
#
#                                               objectURL  \
# 0     https://www.metmuseum.org/art/collection/searc...
# 2     https://www.metmuseum.org/art/collection/searc...
# 7     https://www.metmuseum.org/art/collection/searc...
# 8     https://www.metmuseum.org/art/collection/searc...
# 9     https://www.metmuseum.org/art/collection/searc...
# ...                                                 ...
# 2459  https://www.metmuseum.org/art/collection/searc...
# 2460  https://www.metmuseum.org/art/collection/searc...
# 2461  https://www.metmuseum.org/art/collection/searc...
# 2462  https://www.metmuseum.org/art/collection/searc...
# 2465  https://www.metmuseum.org/art/collection/searc...
#
#                                                    tags  \
# 0     [{'term': 'Bats', 'AAT_URL': 'http://vocab.get...
# 2                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 2459  [{'term': 'Virgin Mary', 'AAT_URL': 'http://vo...
# 2460  [{'term': 'Musical Instruments', 'AAT_URL': 'h...
# 2461  [{'term': 'Interiors', 'AAT_URL': 'http://voca...
# 2462  [{'term': 'Madonna and Child', 'AAT_URL': 'htt...
# 2465  [{'term': 'Men', 'AAT_URL': 'http://vocab.gett...
#
#                             objectWikidata_URL isTimelineWork GalleryNumber  \
# 0                                          NaN          False         214.0
# 2     https://www.wikidata.org/wiki/Q104413096          False           NaN
# 7                                          NaN          False           NaN
# 8                                          NaN          False           NaN
# 9                                          NaN          False           NaN
# ...                                        ...            ...           ...
# 2459   https://www.wikidata.org/wiki/Q19904858          False           NaN
# 2460   https://www.wikidata.org/wiki/Q78760038          False           NaN
# 2461   https://www.wikidata.org/wiki/Q19911530          False           NaN
# 2462   https://www.wikidata.org/wiki/Q19911532          False           NaN
# 2465                                       NaN           True           NaN
#
#      message
# 0        NaN
# 2        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# ...      ...
# 2459     NaN
# 2460     NaN
# 2461     NaN
# 2462     NaN
# 2465     NaN
#
# [1623 rows x 58 columns]

# %% [markdown]
# ### download

# %%
df_sel.shape
# Out:
# (1623, 58)

# %%
download_img(df_sel,'robe/')
# Out:
# start!
# error id 45088
# 1 errors in total
# error id 69010
# 2 errors in total
# error id 85436
# 3 errors in total
# error id 68295
# 4 errors in total
# error id 86895
# 5 errors in total
# error id 81687
# 6 errors in total
# error id 84299
# 7 errors in total
# error id 86178
# 8 errors in total
# error id 38123
# 9 errors in total
# error id 437028
# 10 errors in total
# error id 61833
# 11 errors in total
# error id 468576
# 12 errors in total
# error id 82630
# 13 errors in total
# error id 105411
# 14 errors in total
# error id 84436
# 15 errors in total
# error id 84414
# 16 errors in total
# error id 82158
# 17 errors in total
# error id 436908
# 18 errors in total
# 3763.592482328415 secs slipped...

# %% [markdown]
# ## Asian Art + keywords

# %% [markdown]
# ### download dataframe

# %%
df_asian = pd.read_csv('tran_file\df_asian.csv') # this csv generated in notebook 'data wrangling'
df_asian.shape
# Out:
# (682, 54)

# %%
idlist = df_asian['Object ID'].to_list()
print(f'{len(idlist)} objects')
# Out:
# 682 objects

# %%
df_asian_api = scrapping_by_idlist(idlist)
# Out:
# 111.81104588508606 secs slipped...

# %%
df_asian_api.to_csv('scrapped_data/MET_Asian_Art_Keywords.csv',index=False)

# %%
df_asian_api = pd.read_csv('scrapped_data/MET_Asian_Art_Keywords.csv')

# %% [markdown]
# ### download images

# %%
df_asian_api = df_asian_api[df_asian_api['primaryImage'] != '']

# %%
df_asian_api.shape
# Out:
# (471, 57)

# %%
download_img(df_asian_api,'asian_art/')
# Out:
# start!
# error id 45088
# 1 errors in total
# error id 68295
# 2 errors in total
# error id 69010
# 3 errors in total
# error id 70630
# 4 errors in total
# error id 88642
# 5 errors in total
# error id 97475
# 6 errors in total
# error id 126433
# 7 errors in total
# 598.0307347774506 secs slipped...

# %% [markdown]
# ## Full Selection

# %%
df_full_selection = pd.read_csv('tran_file/df_full_selection.csv')

# %%
df_full_selection.shape
# Out:
# (14292, 54)

# %%
idlist = df_full_selection['Object ID'].to_list()
print(f'{len(idlist)} objects')
# Out:
# 14292 objects

# %% [markdown]
# ### download dataframe

# %%
df_full_selection_api = scrapping_by_idlist(idlist)

# %%
df_full_selection_api.to_csv('scrapped_data/MET_full_selection_Keywords.csv',index=False)

# %%
df_full_selection_api = pd.read_csv('scrapped_data/MET_full_selection_Keywords.csv')

# %% [markdown]
# ### download images

# %%
df_full_selection_api = df_full_selection_api[df_full_selection_api['primaryImage'] != '']

# %%
df_full_selection_api.shape

# %%
download_img(df_full_selection_api,'asian_art/')
